# %% [markdown]
# <a href="https://colab.research.google.com/github/babakara/chatglm_6B_colab/blob/main/chatGLM_6B_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 这是部署在colab上的脚本。

# %%
# !git clone https://github.com/THUDM/ChatGLM-6B.git
# Out:
# Cloning into 'ChatGLM-6B'...
# remote: Enumerating objects: 539, done.
# remote: Counting objects: 100% (95/95), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 539 (delta 62), reused 71 (delta 43), pack-reused 444
# Receiving objects: 100% (539/539), 5.62 MiB | 8.37 MiB/s, done.
# Resolving deltas: 100% (297/297), done.

# %%
# %ls
# %cd ChatGLM-6B
# %ls
# Out:
# ChatGLM-6B/  sample_data/
# /content/ChatGLM-6B
# api.py       LICENSE        ptuning/      requirements.txt  web_demo.py
# cli_demo.py  limitations/   README_en.md  resources/
# examples/    MODEL_LICENSE  README.md     web_demo2.py

# %%
# %pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# 查看当前的GPU情况

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Fri Mar 31 13:32:24 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# 查看当前的内存使用情况

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 27.3 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
from transformers import AutoTokenizer, AutoModel
tokenizer = AutoTokenizer.from_pretrained("THUDM/chatglm-6b", trust_remote_code=True)
model = AutoModel.from_pretrained("THUDM/chatglm-6b", trust_remote_code=True).half().cuda()
model = model.eval()
response, history = model.chat(tokenizer, "你好", history=[])
print(response)
# Out:
# ...
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# ...
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# ...
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# ...
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# 你好👋！我是人工智能助手 ChatGLM-6B，很高兴见到你，欢迎问我任何问题。

# %%
response, history = model.chat(tokenizer, "晚上睡不着应该怎么办", history=history)

# %%
print(response)
# Out:
# 如果晚上睡不着，可以尝试以下方法：
#
# 1. 睡前放松：在睡前半小时尽量避免进行刺激性的活动，放松身心，可以通过冥想、深呼吸等方式缓解紧张情绪。
#
# 2. 创造一个舒适的睡眠环境：保持房间安静、舒适、黑暗，选择舒适的床垫和枕头，确保房间的温度适宜。
#
# 3. 规律作息：保持规律的睡眠时间表，尽量每天在同一时间入睡和起床，帮助身体建立健康的睡眠习惯。
#
# 4. 避免午睡：尽量避免在白天午睡，或限制午睡时间，让身体有足够的时间进入睡眠状态。
#
# 5. 避免饮用咖啡因和饮料：避免在睡前饮用含咖啡因的饮料，如咖啡、茶和可乐，也尽量少吃含糖的食物和饮料，这些都可能影响睡眠。
#
# 如果以上方法不能帮助入睡，建议咨询医生或专业人士，获取更专业的建议和帮助。

# %%
response, history = model.chat(tokenizer, "给霸王防脱洗发水产品写一段广告并列举5个亮点", history=history)

# %%
print(response)
# Out:
# 尊敬的用户，你是否为头发掉落、脱发而苦恼？你是否担心使用了各种洗发水还是无法解决头发问题？现在，我们诚挚地向您推荐霸王防脱洗发水，5大亮点让您摆脱脱发烦恼！
#
# 1. 中药配方，有效防治脱发。霸王防脱洗发水采用了传统的中药配方，经过深入研发，精选了花椒、八角、丁香等多种珍贵中草药，能够温和滋养头皮，促进头发生长，有效防治脱发。
#
# 2. 经过多年的研发，不断创新。霸王防脱洗发水在配方和工艺上不断改进，取得了显著的效果。该产品已经在国内外获得了多项荣誉和认证，备受用户信赖。
#
# 3. 温和无刺激，适合各种发质。霸王防脱洗发水采用了温和的成分，不含任何化学成分，适合各种发质和皮肤类型，能够有效清洁头皮，滋润头发，使头发更加健康有光泽。
#
# 4. 含有多种营养成分，能够滋养头发。霸王防脱洗发水中含有多种营养成分，如维生素B5、B6、氨基酸等，能够滋养头发，增强头发的韧性和弹性，使头发更加浓密有光泽。
#
# 5. 安全可靠，用户口碑相传。霸王防脱洗发水经过多年的研究和临床试验，得到了广大用户的认可和好评，成为了安全可靠的脱发防治产品之一，备受用户喜爱。
#
# 霸王防脱洗发水，让您拥有健康亮丽的头发！

# %% [markdown]
# tcp client connect to remote host.

# %%
# %sudo apt install iputils-ping
# 安装后就可以ping website了
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-12-ed86a7384e39> in <cell line: 1>()
# ----> 1 get_ipython().system('sudo apt install iputils-ping')
#
# /usr/local/lib/python3.9/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      96       kwargs.update({'also_return_output': True})
#      97
# ---> 98     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#      99
#     100     if pip_warn:
#
# /usr/local/lib/python3.9/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     451   # is expected to call this function, thus adding one level of nesting to the
#     452   # stack.
# --> 453   result = _run_command(
#     454       shell.var_expand(cmd, depth=2), clear_streamed_output=False
#     455   )
#
# ...
